# %% [markdown]
# ## Import Libraries

# %%
from quspin.operators import hamiltonian
from quspin.basis import spin_basis_1d
from quspin.basis import spinless_fermion_basis_1d
import numpy as np
import matplotlib.pyplot as plt
import itertools
from quspin.tools.evolution import expm_multiply_parallel
from quspin.operators import quantum_LinearOperator
plt.rcParams['figure.figsize'] = [10, 8]

# %% [markdown]
# ## Define Constants/Helpers

# %%
N = 14
N_filled = N // 2
E_neg1 = 0
P_neg1 = np.exp(-1j * E_neg1)
t = -0.5
g = 1e-3
m = -1
PBC = True

# %%
def stringbox(lst, caption):
    return caption + "-" * (100 - len(caption))+"\n" + str(lst) + "\n" + "-" * 100

# %% [markdown]
# ## Spin Basis Simulation

# %%
spin_basis = spin_basis_1d(N, pauli=-1, Nup=N_filled)
static_terms = []
dynamic_terms = []

### Hopping term
L = (N if PBC else N-1)
hop_coupling = [[-t, i, (i+1) % N] for i in range(L)]
hop_coupling_dag = [[-t, (i+1) % N, i] for i in range(L)]
if PBC and N_filled % 2 == 0:
    hop_coupling[-1][0] = -hop_coupling[-1][0]
    hop_coupling_dag[-1][0] = -hop_coupling_dag[-1][0]
static_terms += [["+-", hop_coupling]]
static_terms += [["+-", hop_coupling_dag]]

### Mass term
mass_coupling = [[m * (-1) ** i, i, i] for i in range(N)]
static_terms += [["+-", mass_coupling]]

### E-field term
def E_squared(n):
    E_const = E_neg1 + (n + 1) // 2
    s_coupling = []
    d_coupling = []
    for i in range(n + 1):
        s_coeff = 2 * E_const * -g
        s_coupling += [[s_coeff, i, i]]
        for j in range(n + 1):
            d_coeff = -g
            d_coupling += [[d_coeff, i, i, j, j]]
    return [["+-", s_coupling], ["+-+-", d_coupling]]
for i in range(N):
    static_terms += E_squared(i)

print(stringbox(static_terms, "Static couplings:"))
### Plotting spectrum
H = hamiltonian(static_terms, dynamic_terms, basis=spin_basis, dtype=np.complex64)
spin_eigvals = H.eigvalsh()
plt.plot(spin_eigvals, ".")
plt.show()
# Out:
# Static couplings:-----------------------------------------------------------------------------------
# [['+-', [[0.5, 0, 1], [0.5, 1, 2], [0.5, 2, 3], [0.5, 3, 4], [0.5, 4, 5], [0.5, 5, 6], [0.5, 6, 7], [0.5, 7, 8], [0.5, 8, 9], [0.5, 9, 10], [0.5, 10, 11], [0.5, 11, 12], [0.5, 12, 13], [0.5, 13, 0]]], ['+-', [[0.5, 1, 0], [0.5, 2, 1], [0.5, 3, 2], [0.5, 4, 3], [0.5, 5, 4], [0.5, 6, 5], [0.5, 7, 6], [0.5, 8, 7], [0.5, 9, 8], [0.5, 10, 9], [0.5, 11, 10], [0.5, 12, 11], [0.5, 13, 12], [0.5, 0, 13]]], ['+-', [[-1, 0, 0], [1, 1, 1], [-1, 2, 2], [1, 3, 3], [-1, 4, 4], [1, 5, 5], [-1, 6, 6], [1, 7, 7], [-1, 8, 8], [1, 9, 9], [-1, 10, 10], [1, 11, 11], [-1, 12, 12], [1, 13, 13]]], ['+-', [[-0.0, 0, 0]]], ['+-+-', [[-0.001, 0, 0, 0, 0]]], ['+-', [[-0.002, 0, 0], [-0.002, 1, 1]]], ['+-+-',
 2, 2, 5, 5], [-0.001, 3, 3, 0, 0], [-0.001, 3, 3, 1, 1], [-0.001, 3, 3, 2, 2], [-0.001, 3, 3, 3, 3], [-0.001, 3, 3, 4, 4], [-0.001, 3, 3, 5, 5], [-0.001, 4, 4, 0, 0], [-0.001, 4, 4, 1, 1], [-0.001, 4, 4, 2, 2], [-0.001, 4, 4, 3, 3], [-0.001, 4, 4, 4, 4], [-0.001, 4, 4, 5, 5], [-0.001, 5, 5, 0, 0], [-0.001, 5, 5, 1, 1], [-0.001, 5, 5, 2, 2], [-0.001, 5, 5, 3, 3], [-0.001, 5, 5, 4, 4], [-0.001, 5, 5, 5, 5]]], ['+-', [[-0.006, 0, 0], [-0.006, 1, 1], [-0.006, 2, 2], [-0.006, 3, 3], [-0.006, 4, 4], [-0.006, 5, 5], [-0.006, 6, 6]]], ['+-+-', [[-0.001, 0, 0, 0, 0], [-0.001, 0, 0, 1, 1], [-0.001, 0, 0, 2, 2], [-0.001, 0, 0, 3, 3], [-0.001, 0, 0, 4, 4], [-0.001, 0, 0, 5, 5], [-0.001, 0, 0, 6, 6], [-0.001, 1, 1, 0, 0], [-0.001, 1, 1, 1, 1], [-0.001, 1, 1, 2, 2], [-0.001, 1, 1, 3, 3], [-0.001, 1, 1, 4, 4], [-0.001, 1, 1, 5, 5], [-0.001, 1, 1, 6, 6], [-0.001, 2, 2, 0, 0], [-0.001, 2, 2, 1, 1], [-0.001, 2, 2, 2, 2], [-0.001, 2, 2, 3, 3], [-0.001, 2, 2, 4, 4], [-0.001, 2, 2, 5, 5], [-0.001, 2, 2, 6, 6], [-0.001, 3, 3, 0, 0], [-0.001, 3, 3, 1, 1], [-0.001, 3, 3, 2, 2], [-0.001, 3, 3, 3, 3], [-0.001, 3, 3, 4, 4], [-0.001, 3, 3, 5, 5], [-0.001, 3, 3, 6, 6], [-0.001, 4, 4, 0, 0], [-0.001, 4, 4, 1, 1], [-0.001, 4, 4, 2, 2], [-0.001, 4, 4, 3, 3], [-0.001, 4, 4, 4, 4], [-0.001, 4, 4, 5, 5], [-0.001, 4, 4, 6, 6], [-0.001, 5, 5, 0, 0], [-0.001, 5, 5, 1, 1], [-0.00 ...
# ----------------------------------------------------------------------------------------------------
# Hermiticity check passed!
# Symmetry checks passed!
# Particle conservation check passed!

# %%
# This is used later in real time dynamics, so keep a copy
H_init = hamiltonian(static_terms, dynamic_terms, basis=spin_basis, dtype=np.complex64)
# Out:
# Hermiticity check passed!
# Symmetry checks passed!
# Particle conservation check passed!

# %% [markdown]
# ## Fermion Basis

# %%
fermion_basis = spinless_fermion_basis_1d(L=N, Nf=N_filled)
static_terms = []
dynamic_terms = []

### Hopping term
L = (N if PBC else N-1)
hop_coupling = [[-t, i, (i+1) % N] for i in range(L)]
hop_coupling_dag = [[-t, (i+1) % N, i] for i in range(L)]
static_terms += [["+-", hop_coupling]]
static_terms += [["+-", hop_coupling_dag]]

### Mass term
mass_coupling = [[m * (-1) ** i, i, i] for i in range(N)]
static_terms += [["+-", mass_coupling]]

### E-field term
# E_link_parity = lambda x : -1 if (x % 4) < 2 else 1
# for i in range(N):
#     E_coupling = [P_neg1 * -g * E_link_parity(i) * 2 ** (i+1)] + list(range(i+1))
#     static_terms += [["z" * (i+1), [E_coupling]]]
def E_squared(n):
    E_const = E_neg1 + (n + 1) // 2
    s_coupling = []
    d_coupling = []
    for i in range(n + 1):
        s_coeff = 2 * E_const * -g
        s_coupling += [[s_coeff, i, i]]
        for j in range(n + 1):
            d_coeff = -g
            d_coupling += [[d_coeff, i, i, j, j]]
    return [["+-", s_coupling], ["+-+-", d_coupling]]
for i in range(N):
    static_terms += E_squared(i)

print(stringbox(static_terms, "Static couplings:"))
### Plotting spectrum
H = hamiltonian(static_terms, dynamic_terms, basis=fermion_basis, dtype=np.float64)
fermion_eigvals = H.eigvalsh()
plt.plot(fermion_eigvals, ".")
plt.show()
# Out:
# Static couplings:-----------------------------------------------------------------------------------
# [['+-', [[0.5, 0, 1], [0.5, 1, 2], [0.5, 2, 3], [0.5, 3, 4], [0.5, 4, 5], [0.5, 5, 6], [0.5, 6, 7], [0.5, 7, 8], [0.5, 8, 9], [0.5, 9, 10], [0.5, 10, 11], [0.5, 11, 12], [0.5, 12, 13], [0.5, 13, 0]]], ['+-', [[0.5, 1, 0], [0.5, 2, 1], [0.5, 3, 2], [0.5, 4, 3], [0.5, 5, 4], [0.5, 6, 5], [0.5, 7, 6], [0.5, 8, 7], [0.5, 9, 8], [0.5, 10, 9], [0.5, 11, 10], [0.5, 12, 11], [0.5, 13, 12], [0.5, 0, 13]]], ['+-', [[-1, 0, 0], [1, 1, 1], [-1, 2, 2], [1, 3, 3], [-1, 4, 4], [1, 5, 5], [-1, 6, 6], [1, 7, 7], [-1, 8, 8], [1, 9, 9], [-1, 10, 10], [1, 11, 11], [-1, 12, 12], [1, 13, 13]]], ['+-', [[-0.0, 0, 0]]], ['+-+-', [[-0.001, 0, 0, 0, 0]]], ['+-', [[-0.002, 0, 0], [-0.002, 1, 1]]], ['+-+-', [[-0.001, 0, 0, 0, 0], [-0.001, 0, 0, 1, 1], [-0.001, 1, 1, 0, 0], [-0.001, 1, 1, 1, 1]]], ['+-', [[-0.002, 0, 0], [-0.002, 1, 1], [-0.002, 2, 2]]], ['+-+-', [[-0.001, 0, 0, 0, 0], [-0.001, 0, 0, 1, 1], [-0.001, 0, 0, 2, 2], [-0.001, 1, 1, 0, 0], [-0.001, 1, 1, 1, 1], [-0.001, 1, 1, 2, 2], [-0.001, 2, 2, 0, 0], [-0.001, 2, 2, 1, 1], [-0.001, 2, 2, 2, 2]]], ['+-', [[-0.004, 0, 0], [-0.004, 1, 1], [-0.004, 2, 2], [-0.004, 3, 3]]], ['+-+-', [[-0.001, 0, 0, 0, 0], [-0.001, 0, 0, 1, 1], [-0.001, 0, 0, 2, 2], [-0.001, 0, 0, 3, 3], [-0.001, 1, 1, 0, 0], [-0.001, 1, 1, 1, 1], [-0.001, 1, 1, 2, 2], [-0.001, 1, 1, 3, 3], [-0.001, 2, 2, 0, 0], [-0.001, 2, 2, 1, 1], [-0.001, 2, 2, 2, 2], [-0.001, 2, 2, 3, 3], [-0.001, 3, 3, 0, 0],
 1, 1, 1, 1], [-0.001, 1, 1, 2, 2], [-0.001, 1, 1, 3, 3], [-0.001, 1, 1, 4, 4], [-0.001, 1, 1, 5, 5], [-0.001, 1, 1, 6, 6], [-0.001, 2, 2, 0, 0], [-0.001, 2, 2, 1, 1], [-0.001, 2, 2, 2, 2], [-0.001, 2, 2, 3, 3], [-0.001, 2, 2, 4, 4], [-0.001, 2, 2, 5, 5], [-0.001, 2, 2, 6, 6], [-0.001, 3, 3, 0, 0], [-0.001, 3, 3, 1, 1], [-0.001, 3, 3, 2, 2], [-0.001, 3, 3, 3, 3], [-0.001, 3, 3, 4, 4], [-0.001, 3, 3, 5, 5], [-0.001, 3, 3, 6, 6], [-0.001, 4, 4, 0, 0], [-0.001, 4, 4, 1, 1], [-0.001, 4, 4, 2, 2], [-0.001, 4, 4, 3, 3], [-0.001, 4, 4, 4, 4], [-0.001, 4, 4, 5, 5], [-0.001, 4, 4, 6, 6], [-0.001, 5, 5, 0, 0], [-0.001, 5, 5, 1, 1], [-0.00 ...
# ----------------------------------------------------------------------------------------------------
# Hermiticity check passed!
# Symmetry checks passed!
# Particle conservation check passed!

# %% [markdown]
# ## Comparison

# %%
mdiff = max(abs(fermion_eigvals - spin_eigvals))
print(stringbox(fermion_eigvals, "Fermion eigenvalues:"))
print(stringbox(spin_eigvals, "Spin eigenvalues:"))
print("Maximum difference between eigenvalues:", mdiff)
# Out:
# Fermion eigenvalues:--------------------------------------------------------------------------------
# [-9.28951707 -7.31761662 -7.25592074 ...  5.76885738  5.82347594
#   7.81158292]
# ----------------------------------------------------------------------------------------------------
# Spin eigenvalues:-----------------------------------------------------------------------------------
# [    0.     0.     0. ...     0.     0. 82368.]
# ----------------------------------------------------------------------------------------------------
# Maximum difference between eigenvalues: 82360.1884170804

# %% [markdown]
# ## Real-time Dynamics

# %%
### Defining time-evolution hamiltonian
spin_basis = spin_basis_1d(N, pauli=-1, Nup=N_filled)
static_terms = []
dynamic_terms = []

### Hopping term
L = (N if PBC else N-1)
hop_coupling = [[-t, i, (i+1) % N] for i in range(L)]
hop_coupling_dag = [[-t, (i+1) % N, i] for i in range(L)]
if PBC and N_filled % 2 == 0:
    hop_coupling[-1][0] = -hop_coupling[-1][0]
    hop_coupling_dag[-1][0] = -hop_coupling_dag[-1][0]
static_terms += [["+-", hop_coupling]]
static_terms += [["+-", hop_coupling_dag]]

### Mass term
mass_coupling = [[-m * (-1) ** i, i, i] for i in range(N)]
static_terms += [["+-", mass_coupling]]

### E-field term
for i in range(N):
    static_terms += E_squared(i)

H = hamiltonian(static_terms, dynamic_terms, basis=spin_basis, dtype=np.complex64)
# Out:
# Hermiticity check passed!
# Symmetry checks passed!
# Particle conservation check passed!

# %%
E_init,V_init=H_init.eigsh(k=1,which='SA',maxiter=1e8)
psi_i=V_init[:,0]
psi_i = psi_i.reshape((-1,))
del H_init

# %%
T = 8#g ** (-1)
dt = T / 500

##### define data type for the simulation
dtype_real = np.float64
dtype_cmplx = np.result_type(dtype_real,np.complex64)
# pre assign arrays
times = np.arange(0,T,dt)                               # times
Lt = np.zeros(len(times),dtype=dtype_real)              # Lohschmidt echo
# construct piece-wise constant unitaries
expH = expm_multiply_parallel(H.tocsr(),a=-1j*dt,dtype=dtype_cmplx)
# auxiliary array for memory efficiency
psi=psi_i.copy().astype(np.complex128)
work_array=np.zeros((2*len(psi),), dtype=psi.dtype) # twice as long because complex_valued
# prepare output
# file_Loschmidt = open(folder_save+'/Loschmidt_rate',"w")
# file_Loschmidt.close
loschmidt = []
for i in range(len(times)):
    if i % (len(times)//10) == 0:
        print("# T = ",times[i])
    Lt[i]=-np.log(np.abs(np.vdot(psi_i,psi)))/N
#     file_Loschmidtfile = open(folder_save+'/Loschmidt_rate',"a")
    print(f"{times[i]}\t {Lt[i]}")#file_Loschmidtfile.write(f"{times[i]}\t {Lt[i]} \n")
    loschmidt += [Lt[i]]
#     file_Loschmidtfile.close()
    expH.dot(psi,work_array=work_array,overwrite_v=True)
# END of time evolution
# Out:
# # T =  0.0
# 0.0	 2.5798861194281393e-08
# 0.016	 7.451695293670748e-05
# 0.032	 0.0002980413618913157
# 0.048	 0.0006707520361309691
# 0.064	 0.001192904561665339
# 0.08	 0.001864857957539478
# 0.096	 0.002687075885167277
# 0.112	 0.003660128218637918
# 0.128	 0.004784692987871946
# 0.14400000000000002	 0.0060615587094686825
# 0.16	 0.0074916271232623914
# 0.176	 0.009075916356035113
# 0.192	 0.010815564537576589
# 0.20800000000000002	 0.012711833898389925
# 0.224	 0.014766115382901419
# 0.24	 0.01697993381710544
# 0.256	 0.019354953675270133
# 0.272	 0.021892985496747387
# 0.28800000000000003	 0.024595993011203656
# 0.304	 0.027466101038868967
# 0.32	 0.030505604241863743
# 0.336	 0.03371697681353024
# 0.352	 0.03710288320521437
# 0.368	 0.040666190004427345
# 0.384	 0.04440997909512866
# 0.4	 0.04833756225046252
# 0.41600000000000004	 0.05245249733119
# 0.432	 0.056758606289945716
# 0.448	 0.061259995213115224
# 0.464	 0.06596107666957962
# 0.48	 0.07086659468000549
# 0.496	 0.07598165267330817
# 0.512	 0.08131174486024793
# 0.528	 0.0868627915301883
# 0.544	 0.09264117886881827
# 0.56	 0.0986538040058311
# 0.5760000000000001	 0.10490812613692382
# 0.592	 0.11141222473007462
# 0.608	 0.11817486602967722
# 0.624	 0.12520557932382864
# 0.64	 0.13251474475303987
# 0.656	 0.14011369483011796
# 0.672	 0.14801483233382642
# 0.6880000000000001	 0.15623176786370224
# 0.704	 0.1647794811412993
# 0.72	 0.1736745111702895
# 0.736	 0.18293518170169437
# 0.752	 0.1925818701990938
# 0.768	 0.20263733081487595
# 0.784	 0.2131270849921542
# # T =  0.8
# 0.8	 0.22407989751888055
# 0.8160000000000001	 0.2355283616588306
# 0.8320000000000001	 0.2475096250949633
# 0.848	 0.26006629997447395
# 0.864	 0.27324761714691254
# 0.88	 0.2871109097056891
# 0.896	 0.30172354922367495
# 0.912	 0.3171655185079274
# 0.928	 0.33353290362056504
# 0.9440000000000001	 0.35094275674087644
# 0.96	 0.36954008382808295
# 0.976	 0.3895082837210565
# 0.992	 0.4110855223817325
# 1.008	 0.43459204745292046
# 1.024	 0.460479459949443
# 7.008	 0.10208343138593337
# 7.024	 0.10075152419150527
# 7.04	 0.09952014299115237
# 7.056	 0.09839666407985259
# 7.072	 0.09738804487068602
# 7.088	 0.09650085572594957
# 7.104	 0.0957413168386401
# 7.12	 0.09511533896682862
# 7.136	 0.09462856705651188
# 7.152	 0.09428642601451345
# 7.168	 0.09409416810689178
# 7.184	 0.09405692165799072
# # T =  7.2
# 7.2	 0.0941797409108217
# 7.216	 0.09446765708291456
# 7.232	 0.09492573081659568
# 7.248	 0.09555910638363563
# 7.264	 0.09637306816733435
# 7.28	 0.097373100117665
# 7.296	 0.09856494906586058
# 7.312	 0.09995469300463959
# 7.328	 0.10154881570263423
# 7.344	 0.10335428934387336
# 7.36	 0.10537866728812038
# 7.376	 0.10763018956589655
# 7.392	 0.11011790439463329
# 7.408	 0.11285180988710437
# 7.424	 0.11584302130111716
# 7.44	 0.11910397076622152
# 7.456	 0.12264864858714776
# 7.472	 0.12649289821283863
# 7.488	 0.1306547811462394
# 7.5040000000000004	 0.13515503402098716
# 7.5200000000000005	 0.14001764866953784
# 7.5360000000000005	 0.14527061865481233
# 7.5520000000000005	 0.15094691471112132
# 7.5680000000000005	 0.1570857806325868
# 7.5840000000000005	 0.1637344868535597
# 7.6000000000000005	 0.17095075275859103
# 7.6160000000000005	 0.17880617162267115
# 7.632000000000001	 0.1873911839321716
# 7.648000000000001	 0.19682252508697134
# 7.664000000000001	 0.20725478848214224
# 7.68	 0.218899164624872
# 7.696	 0.2320554234752587
# 7.712	 0.24717008558982312
# 7.728	 0.26495099863896426
# 7.744	 0.2866169483937804
# 7.76	 0.31451251195017
# 7.776	 0.3537452671873319
# 7.792	 0.4097208391729553
# 7.808	 0.39565344544681896
# 7.824	 0.3530862734877483
# 7.84	 0.32741531226228066
# 7.856	 0.3109184694505323
# 7.872	 0.29975651984844126
# 7.888	 0.2921147720626657
# 7.904	 0.2870256297957419
# 7.92	 0.28392429354176146
# 7.936	 0.28246041784344444
# 7.952	 0.2824083783456038
# 7.968	 0.2836201708753683
# 7.984	 0.285998399137909

# %%
plt.plot(times, loschmidt)

# %% [markdown]
# ## Joe OTOC Calculation Attempt

# %%
#psi_ground at t=0 correlated with psi_top at t=1

##### define data type for the simulation
dtype_real = np.float64
dtype_cmplx = np.result_type(dtype_real,np.complex64)
# pre assign arrays
times = np.arange(0,T,dt)                               # times
Lt = np.zeros(len(times),dtype=dtype_real)              # Lohschmidt echo
# construct piece-wise constant unitaries
expH = expm_multiply_parallel(H.tocsr(),a=-1j,dtype=dtype_cmplx)
# auxiliary array for memory efficiency

print(len(psi_i))
psi=psi_i.copy().astype(np.complex128)
work_array=np.zeros((2*len(psi),), dtype=psi.dtype) # twice as long because complex_valued
# prepare output
i = 1
expH.dot(psi,work_array=work_array,overwrite_v=True)

correlator = np.dot(psi_i, psi)
print("Correlator:",correlator)
# END of time evolution
# Out:
# 3432
# Correlator: (0.0016016624919936635-0.002168520013849571j)

# %% [markdown]
# ## Drew Correlator calculation (Eqn. 2 of Niklas's paper)

# %%
c0_static = [["-",[[1.0,0]]]]
creator = quantum_LinearOperator(c0_static,basis=spin_basis,dtype=np.complex128,check_herm=False,check_pcon=False)
def cdag(n):
    cdag_static = [["+",[[1.0,n]]]]
    cdagn = quantum_LinearOperator(cdag_static,basis=spin_basis,dtype=np.complex128,check_herm=False,check_pcon=False)
    return(cdagn)
annihilators = [cdag(n) for n in range(N)]
# Out:
# Symmetry checks passed!
# Symmetry checks passed!
# Symmetry checks passed!
# Symmetry checks passed!
# Symmetry checks passed!
# Symmetry checks passed!
# Symmetry checks passed!
# Symmetry checks passed!
# Symmetry checks passed!
# Symmetry checks passed!
# Symmetry checks passed!
# Symmetry checks passed!
# Symmetry checks passed!
# Symmetry checks passed!
# Symmetry checks passed!

# %%
##### define data type for the simulation
dtype_real = np.float64
dtype_cmplx = np.result_type(dtype_real,np.complex64)
# pre assign arrays
times = np.arange(0,T,dt)                               # times
# time-evolution operator
expmiH = expm_multiply_parallel(H.tocsr(),a=-1j,dtype=dtype_cmplx)

# array to store correlators expectations from psi(t,n) to psi(0,0)
correlators = [0 for i in range(N)]

leftPsi=psi_i.copy().astype(np.complex128) #state for left-half of inner product
rightPsi=psi_i.copy().astype(np.complex128) #state for right-half
for n in range(N): #loop over all sites
    for i in range(len(times)): #loop over times (for annhilator location)
        expmiH.dot(leftPsi,overwrite_v=True)
        leftPsi.dot(annihilators[n].conjugate()) # <psi_0| . e^(iHt) . psidagger(n)
        rightPsi.dot(creator)
        expmiH.dot(rightPsi,overwrite_v=True)  # e^(-iHt) . psi(0,0) . |psi_0>
        correlators[n] += leftPsi.dot(rightPsi) # <psi_0| . e^(iHt) . psidagger(n) . e^(-iHt) . psi(0,0) . |psi_0>
correlators = [l/N for l in correlators] # Averaging over N so that it is actually an expectation value
print("Correlators:",correlators) #This is expectation(correlators(n)) as a function
# END of time evolution
# Out:
# Correlators: [(0.0036866905570443415-0.02244951920920602j), (-0.005791339792546587+0.0033176455181151577j), (-0.01173231589577979+0.011980987344032877j), (-0.03092070663155963+0.017238965540419173j), (0.015098194597563862+0.015757484912394103j), (0.008069564759234024+0.030130344045865176j), (0.008842495203544286+0.018898777394651484j), (0.038184402867802565+0.01536014087375415j), (0.01679081841460329-0.025659920298492747j), (0.025516951468044897+0.014686657913590964j), (0.017349894653067414-0.006025723176957928j), (0.0006196211478687795-0.029192941751430286j), (0.0172751476178851+0.009624242764917744j), (0.027314896164639405-0.028956779414878085j)]

# %%
correlatorfft = np.fft.fft(correlators,axis=0)

# %%
plt.plot(np.imag(correlatorfft))
plt.plot(np.real(correlatorfft))

# %%
plt.plot(np.imag(correlators),color='red',label="Imaginary Part")
plt.plot(np.real(correlators),color='blue',label="Real Part")
plt.title("creation-annihilation correlator e-value")
plt.ylabel("correlator expectation value")
plt.xlabel("lattice site n")
plt.figlegend()

# %%
for i in correlators:
    print(abs(i))
# Out:
# 0.022750221976673327
# 0.006674308082236176
# 0.016768759465632607
# 0.03540158233043737
# 0.02182324015517023
# 0.03119223473439623
# 0.02086512660966364
# 0.04115801926760108
# 0.0306653402517758
# 0.029441683594750533
# 0.018366496243918302
# 0.029199516750612293
# 0.019775155473922137
# 0.03980701730307032
